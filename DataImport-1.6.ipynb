# %%
import datetime as dt
import pandas as pd
from pandas_datareader import data as pdr
import plotly.offline as plotly
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import yfinance as yf
yf.pdr_override()
import os
plotly.init_notebook_mode(connected=True)
pd.options.plotting.backend = 'plotly'
import wrds
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Specifying date range

# %%
# selecting dates to be 10 year window after Feng et al. 2012's paper
end = dt.datetime(2023, 1, 1)
start = dt.datetime(2013, 1, 1)
start, end
# Out:
# (datetime.datetime(2013, 1, 1, 0, 0), datetime.datetime(2023, 1, 1, 0, 0))

# %% [markdown]
# ## Select stock/ticker

# %% [markdown]
# # Importing stock tickers from
# from https://stockmarketmba.com/stocksinthesp500.php

# %%
working_dir = os.getcwd()

# %%
os.listdir(working_dir)
# Out:
# ['.git',
#  'data',
#  'DataImport-1.1.ipynb',
#  'DataImport-1.2.ipynb',
#  'DataImport-1.3.ipynb',
#  'DataImport-1.4.ipynb',
#  'DataImport-1.5.ipynb',
#  'model_test.py',
#  'PCS_Update.ipynb',
#  'README.md',
#  'Stock Data analysis.ipynb',
#  'Stock_Data_analysis.ipynb',
#  'stock_volume_WRDS_query.txt',
#  'Stock_volume_WRDS_query_csv.csv',
#  'Stock_volume_WRDS_query_csv.zip',
#  'Trail_Agent_code.ipynb',
#  'used_ticker_list.txt']

# %%
path = "data/Stocks_in_SP_500_Index.xlsx"
data = pd.read_excel(path,skiprows=1)
data.head()
# Out:
#   Symbol           Description      Category2  Category3  \
# 0   AAPL             Apple Inc  Common stocks  Large cap
# 1   MSFT        Microsoft Corp  Common stocks  Large cap
# 2   GOOG  Alphabet Inc Class C  Common stocks  Large cap
# 3  GOOGL  Alphabet Inc Class A  Common stocks  Large cap
# 4   AMZN       Amazon.Com Inc.  Common stocks  Large cap
#
#               GICS Sector     Market cap  Dividend yield  \
# 0  Information Technology  1988832912360          0.0073
# 1  Information Technology  1657655067218          0.0114
# 2  Communication Services  1042954820000          0.0000
# 3  Communication Services  1042954820000          0.0000
# 4  Consumer Discretionary   847961495109          0.0000
#
#    Price to TTM earnings  Price to TTM sales  Price to book value   Action
# 0                      0                   0                    0  Analyze
# 1                      0                   0                    0  Analyze
# 2                      0                   0                    0  Analyze
# 3                      0                   0                    0  Analyze
# 4                      0                   0                    0  Analyze

# %%
tickers = data['Symbol'].to_list()

# %%
tickers
# Out:
# ['AAPL',
#  'MSFT',
#  'GOOG',
#  'GOOGL',
#  'AMZN',
#  'BRK.B',
#  'JNJ',
#  'UNH',
#  'XOM',
#  'V',
#  'JPM',
#  'WMT',
#  'PG',
#  'NVDA',
#  'TSLA',
#  'META',
#  'LLY',
#  'CVX',
#  'MA',
#  'HD',
#  'ABBV',
#  'MRK',
#  'PFE',
#  'BAC',
#  'KO',
#  'PEP',
#  'AVGO',
#  'ORCL',
#  'TMO',
#  'COST',
#  'ABT',
#  'CSCO',
#  'MCD',
#  'NKE',
#  'DHR',
#  'TMUS',
#  'VZ',
#  'ACN',
#  'DIS',
#  'NEE',
#  'WFC',
#  'CMCSA',
#  'PM',
#  'BMY',
#  'ADBE',
#  'TXN',
#  'SCHW',
#  'LIN',
#  'UPS',
#  'RTX',
#  'COP',
#  'MS',
#  'AMGN',
#  'HON',
#  'T',
#  'NFLX',
#  'CRM',
#  'IBM',
#  'CAT',
#  'LMT',
#  'UNP',
#  'LOW',
#  'DE',
#  'QCOM',
#  'BA',
#  'SBUX',
#  'CVS',
#  'GS',
#  'INTC',
#  'ELV',
#  'SPGI',
#  'AXP',
#  'GILD',
#  'MDT',
#  'INTU',
#  'BLK',
#  'PLD',
#  'AMD',
#  'AMT',
#  'ADP',
#  'ISRG',
#  'SYK',
#  'EL',
#  'TJX',
#  'CI',
#  'CB',
#  'C',
#  'MDLZ',
#  'PYPL',
#  'BKNG',
#  'AMAT',
#  'MMC',
#  'NOC',
#  'ADI',
#  'MO',
#  'DUK',
#  'GE',
#  'REGN',
#  'PGR',
#  'SO',
#  'SLB',
#  'VRTX',
#  'NOW',
#  'EOG',
#  'BDX',
#  'TGT',
#  'HCA',
#  'ZTS',
#  'MMM',
#  'USB',
#  'ITW',
#  'GD',
#  'APD',
#  'MRNA',
#  'CL',
#  'BSX',
#  'WM',
#  'CSX',
#  'PNC',
#  'FISV',
#  'ETN',
#  'AON',
#  'HUM',
#  'EQIX',
#  'CME',
#  'CCI',
#  'ATVI',
#  'MU',
#  'SHW',
#  'TFC',
#  'ICE',
#  'NSC',
#  'MET',
#  'FCX',
#  'LRCX',
#  'OXY',
#  'CHTR',
#  'EMR',
#  'PXD',
#  'DG',
#  'MPC',
#  'MCK',
#  'KLAC',
#  'MNST',
#  'ORLY',
#  'D',
#  'MCO',
#  'KHC',
#  'KDP',
#  'GIS',
#  'GM',
#  'VLO',
#  'PSX',
#  'F',
#  'AEP',
#  'SNPS',
#  'SRE',
#  'PSA',
#  'AIG',
#  'MAR',
#  'EW',
#  'ADM',
#  'ROP',
#  'FDX',
#  'HSY',
#  'KMB',
#  'APH',
#  'AZO',
#  'A',
#  'JCI',
#  'AFL',
#  'CTAS',
#  'TRV',
#  'CNC',
#  'HES',
#  'DXCM',
#  'CDNS',
#  'MSI',
#  'EXC',
#  'CTVA',
#  'ECL',
#  'PAYX',
#  'KMI',
#  'ROST',
#  'NEM',
#  'FIS',
#  'NXPI',
#  'O',
#  'WMB',
#  'RSG',
#  'TT',
#  'LVS',
#  'DVN',
#  'AJG',
#  'ADSK',
#  'LHX',
#  'BIIB',
#  'XEL',
#  'SYY',
#  'IQV',
#  'SPG',
#  'PH',
#  'BK',
#  'MCHP',
#  'CMG',
#  'DOW',
#  'FTNT',
#  'PRU',
#  'ALL',
#  'TEL',
#  'MSCI',
#  'YUM',
#  'COF',
#  'HAL',
#  'DD',
#  'NUE',
#  'CARR',
#  'IDXX',
#  'TDG',
#  'EA',
#  'HLT',
#  'PCAR',
#  'ED',
#  'STZ',
#  'ABC',
#  'ANET',
#  'CMI',
#  'OTIS',
#  'MTD',
#  'WELL',
#  'AMP',
#  'ENPH',
#  'KR',
#  'DLTR',
#  'DHI',
#  'AME',
#  'ILMN',
#  'WBA',
#  'PCG',
#  'ODFL',
#  'VICI',
#  'BF.B',
#  'PEG',
#  'CSGP',
#  'SBAC',
#  'KEYS',
#  'RMD',
#  'WEC',
#  'ROK',
#  'NDAQ',
#  'CTSH',
#  'ES',
#  'GLW',
#  'OKE',
#  'PPG',
#  'STT',
#  'BKR',
#  'VRSK',
#  'LYB',
#  'DLR',
#  'AWK',
#  'GPN',
#  'WBD',
#  'WTW',
#  'IFF',
#  'DFS',
#  'GWW',
#  'CEG',
#  'HPQ',
#  'LEN',
#  'FAST',
#  'BAX',
#  'ZBH',
#  'APTV',
#  'ON',
#  'IT',
#  'ALB',
#  'MTB',
#  'URI',
#  'HRL',
#  'ULTA',
#  'EIX',
#  'CBRE',
#  'HIG',
#  'TSCO',
#  'EFX',
#  'TROW',
#  'CDW',
#  'VMC',
#  'K',
#  'FE',
#  'GPC',
#  'FANG',
#  'ARE',
#  'EBAY',
#  'ACGL',
#  'WY',
#  'TSN',
#  'RJF',
#  'FITB',
#  'MKC',
#  'FTV',
#  'DAL',
#  'DTE',
#  'AEE',
#  'AVB',
#  'VRSN',
#  'EQR',
#  'FRC',
#  'IR',
#  'PPL',
#  'LH',
#  'ETR',
#  'HPE',
#  'MLM',
#  'PFG',
#  'HBAN',
#  'RF',
#  'ANSS',
#  'CAH',
#  'XYL',
#  'CHD',
#  'CFG',
#  'LUV',
#  'WRB',
#  'PWR',
#  'CAG',
#  'WAT',
#  'VTR',
#  'HOLX',
#  'NTRS',
#  'EXR',
#  'DOV',
#  'STE',
#  'TDY',
#  'CTRA',
#  'WAB',
#  'CMS',
#  'GRMN',
#  'CNP',
#  'BBY',
#  'EPAM',
#  'ROL',
#  'INCY',
#  'TTWO',
#  'AMCR',
#  'PAYC',
#  'MAA',
#  'DGX',
#  'DRI',
#  'CLX',
#  'PKI',
#  'JBHT',
#  'INVH',
#  'MOH',
#  'OMC',
#  'STLD',
#  'AES',
#  'WST',
#  'ALGN',
#  'IEX',
#  'SJM',
#  'CPB',
#  'CINF',
#  'COO',
#  'EXPD',
#  'KEY',
#  'BALL',
#  'LYV',
#  'CF',
#  'MRO',
#  'MPWR',
#  'FOX',
#  'FOXA',
#  'HWM',
#  'BRO',
#  'TRGP',
#  'BR',
#  'J',
#  'FSLR',
#  'SEDG',
#  'ATO',
#  'FMC',
#  'MOS',
#  'ETSY',
#  'FDS',
#  'NVR',
#  'AVY',
#  'SWKS',
#  'VTRS',
#  'TXT',
#  'EVRG',
#  'CPRT',
#  'LKQ',
#  'SYF',
#  'IRM',
#  'LDOS',
#  'PTC',
#  'ZBRA',
#  'L',
#  'EXPE',
#  'PEAK',
#  'KIM',
#  'LW',
#  'SIVB',
#  'GEN',
#  'IPG',
#  'BEN',
#  'RCL',
#  'LNT',
#  'TER',
#  'MGM',
#  'UAL',
#  'APA',
#  'RE',
#  'ESS',
#  'AKAM',
#  'FLT',
#  'NTAP',
#  'NDSN',
#  'CBOE',
#  'IP',
#  'TYL',
#  'BIO',
#  'JKHY',
#  'TRMB',
#  'PARA',
#  'SNA',
#  'UDR',
#  'CE',
#  'PKG',
#  'DPZ',
#  'MTCH',
#  'TFX',
#  'POOL',
#  'WDC',
#  'EQT',
#  'GL',
#  'CPT',
#  'SWK',
#  'VFC',
#  'HST',
#  'MKTX',
#  'CRL',
#  'STX',
#  'NI',
#  'UHS',
#  'PHM',
#  'MAS',
#  'HSIC',
#  'NWS',
#  'NWSA',
#  'BBWI',
#  'REG',
#  'WYNN',
#  'CHRW',
#  'EMN',
#  'JNPR',
#  'BXP',
#  'KMX',
#  'CCL',
#  'BWA',
#  'TPR',
#  'ALLE',
#  'WRK',
#  'AAP',
#  'QRVO',
#  'CZR',
#  'AAL',
#  'AOS',
#  'CDAY',
#  'HII',
#  'HAS',
#  'CMA',
#  'IVZ',
#  'FFIV',
#  'FRT',
#  'PNW',
#  'CTLT',
#  'WHR',
#  'RHI',
#  'DISH',
#  'RL',
#  'ZION',
#  'PNR',
#  'OGN',
#  'NRG',
#  'SEE',
#  'XRAY',
#  'MHK',
#  'DVA',
#  'SBNY',
#  'AIZ',
#  'DXC',
#  'GNRC',
#  'NWL',
#  'LUMN',
#  'ALK',
#  'NCLH',
#  'LNC',
#  'VNO',
#  'TECH',
#  'TAP']

# %% [markdown]
# ## pandas_datareader module

# %%
# 1. pdr.DataReader(stocks, 'yahoo', start, end)
# 2. pdr.get_data_yahoo(stocks, start, end)

df = pdr.get_data_yahoo(tickers, start, end)
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 2 Failed downloads:
# - BF.B: No data found for this date range, symbol may be delisted
# - BRK.B: No data found for this date range, symbol may be delisted

# %% [markdown]
# # Making a DataFrame containing Adjusted close Daily returns

# %%
df['Adj Close'].columns
# Out:
# Index(['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABT', 'ACGL', 'ACN', 'ADBE',
#        ...
#        'WYNN', 'XEL', 'XOM', 'XRAY', 'XYL', 'YUM', 'ZBH', 'ZBRA', 'ZION',
#        'ZTS'],
#       dtype='object', length=503)

# %%
#checking for missing values & printing the columns with missing values
col_with_missing_values = {}
for col in df['Adj Close'].columns:
    # counting the columns with missing values in Adj Close
    sum_of_missing_values = df['Adj Close'][col].isnull().sum()
    # also counting the columns with missing values in Volume
    sum_of_missing_values += df['Volume'][col].isnull().sum()
    if sum_of_missing_values > 0:
        col_with_missing_values[col] = sum_of_missing_values
        print(col)
# Out:
# ALLE
# ANET
# BF.B
# BRK.B
# CARR
# CDAY
# CDW
# CEG
# CFG
# CTLT
# CTVA
# CZR
# DOW
# ETSY
# FOX
# FOXA
# FTV
# HLT
# HPE
# HWM
# INVH
# IQV
# IR
# KEYS
# KHC
# LW
# MRNA
# NCLH
# NWS
# NWSA
# OGN
# OTIS
# PAYC
# PYPL
# QRVO
# SEDG
# SYF
# VICI
# WRK
# ZTS

# %%
df_col_missing_values = pd.DataFrame(col_with_missing_values, index = [0]).T
df_col_missing_values.columns = ['Missing Values']

# %%
list_of_tickers_with_missing_values = df_col_missing_values.index.to_list()

# %%
print(f'stocks with missing values {list_of_tickers_with_missing_values}')
print(f'stocks to de removed: {len(list_of_tickers_with_missing_values)}')
# Out:
# stocks with missing values ['ALLE', 'ANET', 'BF.B', 'BRK.B', 'CARR', 'CDAY', 'CDW', 'CEG', 'CFG', 'CTLT', 'CTVA', 'CZR', 'DOW', 'ETSY', 'FOX', 'FOXA', 'FTV', 'HLT', 'HPE', 'HWM', 'INVH', 'IQV', 'IR', 'KEYS', 'KHC', 'LW', 'MRNA', 'NCLH', 'NWS', 'NWSA', 'OGN', 'OTIS', 'PAYC', 'PYPL', 'QRVO', 'SEDG', 'SYF', 'VICI', 'WRK', 'ZTS']
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.012852  0.026445  0.011118 -0.000728  0.000621  0.001106
# 2022-12-27  0.009023  0.013894  0.007540  0.009022  0.007758  0.004657
# 2022-12-28 -0.013972 -0.016426 -0.033988 -0.016077 -0.004542 -0.010135
# 2022-12-29  0.007085  0.007566  0.046184  0.024784  0.005259  0.014604
# 2022-12-30 -0.013508  0.010073 -0.013631 -0.009584 -0.014693 -0.002582
#
#                 ZBRA      ZION
# Date
# 2013-01-03  0.000977  0.001364
# 2013-01-04 -0.008049  0.028610
# 2013-01-07  0.005655 -0.004857
# 2013-01-08  0.000733 -0.019964
# 2013-01-09  0.010750 -0.010865
# ...              ...       ...
# 2022-12-23  0.002869  0.003521
# 2022-12-27  0.011200  0.008050
# 2022-12-28 -0.016574 -0.017813
# 2022-12-29  0.043307  0.023139
# 2022-12-30 -0.004349  0.001630
#
# [2517 rows x 463 columns]

# %%
used_ticker_symbols = df_clean_daily_returns.columns
used_ticker_symbols
# Out:
# Index(['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABT', 'ACGL', 'ACN', 'ADBE',
#        ...
#        'WY', 'WYNN', 'XEL', 'XOM', 'XRAY', 'XYL', 'YUM', 'ZBH', 'ZBRA',
#        'ZION'],
#       dtype='object', length=463)

# %%
with open(r'C:\Users\Nitai Nijholt\OneDrive\Desktop\project computational science\PCS_Financial_Market_ABM\used_ticker_list.txt', 'w') as file:
    for item in used_ticker_symbols:
        file.write("%s\n" % item)
    print('done')
# Out:
# done

# %%
# stock volume data row used belpw: https://www.dropbox.com/s/c9nf1lh3sdggsp0/Stock_sharesoutstanding_WRDS_query_csv.csv?dl=0

# %%
volume_stock_data = pd.read_csv(r'C:\Users\Nitai Nijholt\OneDrive\Desktop\project computational science\PCS_Financial_Market_ABM\stock_volume_WRDS_query_csv.csv', parse_dates=True, index_col=2)
# Out:
# C:\Users\Nitai Nijholt\AppData\Local\Temp\ipykernel_10604\2715502419.py:1: DtypeWarning:
#
# Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
volume_stock_data.columns
# Out:
# Index(['gvkey', 'iid', 'tic', 'conm', 'cshtrd'], dtype='object')

# %%
volume_stock_data
# Out:
#              gvkey iid    tic                          conm      cshtrd
# datadate
# 2007-01-03    1045  01  AAMRQ   AMERICAN AIRLINES GROUP INC  12096600.0
# 2007-01-04    1045  01  AAMRQ   AMERICAN AIRLINES GROUP INC   9454800.0
# 2007-01-05    1045  01  AAMRQ   AMERICAN AIRLINES GROUP INC   7861900.0
# 2007-01-08    1045  01  AAMRQ   AMERICAN AIRLINES GROUP INC   7896300.0
# 2007-01-09    1045  01  AAMRQ   AMERICAN AIRLINES GROUP INC   7045300.0
# ...            ...  ..    ...                           ...         ...
# 2010-11-30  294524   2  LYB.B  LYONDELLBASELL INDUSTRIES NV    310980.0
# 2010-12-01  294524   2  LYB.B  LYONDELLBASELL INDUSTRIES NV    832088.0
# 2010-12-02  294524   2  LYB.B  LYONDELLBASELL INDUSTRIES NV    451115.0
# 2010-12-03  294524   2  LYB.B  LYONDELLBASELL INDUSTRIES NV    360461.0
# 2010-12-06  294524   2  LYB.B  LYONDELLBASELL INDUSTRIES NV    165050.0
#
# [2440295 rows x 5 columns]

# %%
volume_stock_data
# Out:
#              gvkey iid    tic                          conm      cshtrd
# datadate
# 2007-01-03    1045  01  AAMRQ   AMERICAN AIRLINES GROUP INC  12096600.0
# 2007-01-04    1045  01  AAMRQ   AMERICAN AIRLINES GROUP INC   9454800.0
# 2007-01-05    1045  01  AAMRQ   AMERICAN AIRLINES GROUP INC   7861900.0
# 2007-01-08    1045  01  AAMRQ   AMERICAN AIRLINES GROUP INC   7896300.0
# 2007-01-09    1045  01  AAMRQ   AMERICAN AIRLINES GROUP INC   7045300.0
# ...            ...  ..    ...                           ...         ...
# 2010-11-30  294524   2  LYB.B  LYONDELLBASELL INDUSTRIES NV    310980.0
# 2010-12-01  294524   2  LYB.B  LYONDELLBASELL INDUSTRIES NV    832088.0
# 2010-12-02  294524   2  LYB.B  LYONDELLBASELL INDUSTRIES NV    451115.0
# 2010-12-03  294524   2  LYB.B  LYONDELLBASELL INDUSTRIES NV    360461.0
# 2010-12-06  294524   2  LYB.B  LYONDELLBASELL INDUSTRIES NV    165050.0
#
# [2440295 rows x 5 columns]

# %%
volume_stock_data = volume_stock_data.drop(columns=['gvkey', 'iid', 'conm'])

# %%
volume_stock_data
# Out:
#               tic      cshtrd
# datadate
# 2007-01-03  AAMRQ  12096600.0
# 2007-01-04  AAMRQ   9454800.0
# 2007-01-05  AAMRQ   7861900.0
# 2007-01-08  AAMRQ   7896300.0
# 2007-01-09  AAMRQ   7045300.0
# ...           ...         ...
# 2010-11-30  LYB.B    310980.0
# 2010-12-01  LYB.B    832088.0
# 2010-12-02  LYB.B    451115.0
# 2010-12-03  LYB.B    360461.0
# 2010-12-06  LYB.B    165050.0
#
# [2440295 rows x 2 columns]

# %%
volume_stock_data['tic'].nunique()
# Out:
# 970

# %%
volume_stock_data.tic.nunique()
# Out:
# 970

# %%
volume_stock_data[ 'Date'] = volume_stock_data.index

# %%
volume_stock_data
# Out:
#               tic      cshtrd       Date
# datadate
# 2007-01-03  AAMRQ  12096600.0 2007-01-03
# 2007-01-04  AAMRQ   9454800.0 2007-01-04
# 2007-01-05  AAMRQ   7861900.0 2007-01-05
# 2007-01-08  AAMRQ   7896300.0 2007-01-08
# 2007-01-09  AAMRQ   7045300.0 2007-01-09
# ...           ...         ...        ...
# 2010-11-30  LYB.B    310980.0 2010-11-30
# 2010-12-01  LYB.B    832088.0 2010-12-01
# 2010-12-02  LYB.B    451115.0 2010-12-02
# 2010-12-03  LYB.B    360461.0 2010-12-03
# 2010-12-06  LYB.B    165050.0 2010-12-06
#
# [2440295 rows x 3 columns]

# %%
volume_stock_data_clean_pivot = volume_stock_data.pivot(index = 'Date', columns='tic',values = 'cshtrd')

# %%
volume_stock_data_clean_pivot
# Out:
# tic         0050B  0051B  1974B  2091B  3CCIKO  4741B  4764B  5050B  5235B  \
# Date
# 2007-01-02    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN
# 2007-01-03    NaN    NaN    NaN    NaN     0.0    NaN    NaN    0.0    NaN
# 2007-01-04    NaN    NaN    NaN    NaN     0.0    NaN    NaN    0.0    NaN
# 2007-01-05    NaN    NaN    NaN    NaN     0.0    NaN    NaN    0.0    NaN
# 2007-01-08    NaN    NaN    NaN    NaN     0.0    NaN    NaN    0.0    NaN
# ...           ...    ...    ...    ...     ...    ...    ...    ...    ...
# 2023-01-09    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN
# 2023-01-10    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN
# 2023-01-11    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN
# 2023-01-12    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN
# 2023-01-13    NaN    NaN    NaN    NaN     NaN    NaN    NaN    NaN    NaN
#
# tic         5236B  ...  ZB.PF        ZBH  ZBH.WI      ZBRA       ZION  ZIONN  \
# Date               ...
# 2007-01-02    NaN  ...    NaN        NaN     NaN       NaN        NaN    NaN
# 2007-01-03    NaN  ...    NaN  1792300.0     NaN  560760.0   693041.0    NaN
# 2007-01-04    NaN  ...    NaN  2053000.0     NaN  355633.0   569895.0    NaN
# 2007-01-05    NaN  ...    NaN  1220400.0     NaN  645339.0   829044.0    NaN
# 2007-01-08    NaN  ...    NaN  1806100.0     NaN  318215.0   620257.0    NaN
# ...           ...  ...    ...        ...     ...       ...        ...    ...
# 2023-01-09    NaN  ...    NaN  1423625.0     NaN  535362.0   902684.0    NaN
# 2023-01-10    NaN  ...    NaN  1894247.0     NaN  353624.0   878534.0    NaN
# 2023-01-11    NaN  ...    NaN  2448268.0     NaN  600101.0   697494.0    NaN
# 2023-01-12    NaN  ...    NaN  1888908.0     NaN  735454.0  1295242.0    NaN
# 2023-01-13    NaN  ...    NaN  1674106.0     NaN  687092.0  1018734.0    NaN
#
# tic           ZIONO    ZIONP  ZIONW  ZIONZ
# Date
# 2007-01-02      NaN      NaN    NaN    NaN
# 2007-01-03      NaN      0.0    NaN    NaN
# 2007-01-04      NaN      0.0    NaN    NaN
# 2007-01-05      NaN    500.0    NaN    NaN
# 2007-01-08      NaN  12700.0    NaN    NaN
# ...             ...      ...    ...    ...
# 2023-01-09   7514.0   2320.0    NaN    NaN
# 2023-01-10   6911.0   1305.0    NaN    NaN
# 2023-01-11   3202.0   1295.0    NaN    NaN
# 2023-01-12  13750.0   4946.0    NaN    NaN
# 2023-01-13   4708.0   3074.0    NaN    NaN
#
# [4071 rows x 970 columns]

# %%
volume_stock_data_clean_pivot.shape
# Out:
# (4071, 970)

# %%
for col in volume_stock_data_clean_pivot.columns:
    print(col, volume_stock_data_clean_pivot[col].isnull().sum())
# Out:
# 0050B 4071
# 0051B 4071
# 1974B 4071
# 2091B 4071
# 3CCIKO 2741
# 4741B 4055
# 4764B 4071
# 5050B 3490
# 5235B 4071
# 5236B 4071
# 5237B 4071
# 5238B 4071
# 6525B 4068
# 9297B 4071
# A 34
# AAL 1780
# AALCP 3988
# AAMRQ 2325
# AAP 34
# AAPL 34
# AAR 2809
# ABBV 1529
# ABC 34
# ABT 34
# ACE.PC 3707
# ACGL 34
# ACGLN 3663
# ACGLO 2707
# ACGLP 2814
# ACN 34
# ADBE 34
# ADI 34
# ADM 34
# ADM.PA 3314
# ADP 34
# ADSK 34
# AEE 34
# AEP 34
# AEP.PA 2871
# AEPPL 3322
# AEPPZ 3465
# AES 34
# AESC 3607
# AFL 34
# AHC.2 4071
# AIG 34
# AIG.PA 3104
# AIG.PA.1 3264
# AIG.WS 1554
# AIZ 34
# AIZP 3312
# AJG 34
# AKAM 34
# ALB 34
# ALGN 34
# ALK 34
# ALL 34
# ALL.PA 2409
# ALL.PC 2799
# ALL.PD 2610
# ALL.PE 2652
# ALL.PF 2725
# ALL.PG 2863
# ALL.PH 3206
# ALL.PI 3273
# AMAT 34
# AMCO30 962
# AMCR 3164
# AMD 34
# AME 34
# AMGN 34
# AMP 34
# AMP.PA 2806
# AMT 34
# AMT.PA 3311
# AMT.PB 3322
# AMZN 34
# ANSS 34
# ANTX.2 3324
# AON 34
# AOS 34
# APA 34
# APA.PD 3310
# APD 34
# APH 34
# APTV 1264
# APTV.PA 3420
# ARE 34
# ARE.PB 4019
# ARE.PC 2742
# ARE.PD 1195
# ARE.PE 2788
# ARH.PA 2728
# ARH.PB 2728
# ARH.PC 2628
# ATO 34
# ATVI 416
# AVB 34
# AVB.PH 3621
# AVGO 687
# AVGOP 3311
# AVY 34
# AWK 362
# AXP 34
# AZO 34
# BA 34
# BAC 34
# BAC.PA 2809
# BAC.PB 2897
# BAC.PC 2807
# BAC.PD 1125
# BAC.PE 34
# BAC.PH 2828
# BAC.PI 1360
# BAC.PJ 2637
# BAC.PK 2939
# BAC.PL 302
# BAC.PM 3175
# BAC.PN 3233
# BAC.PO 3518
# BAC.PP 3577
# BAC.PQ 3765
# BAC.PS 3833
# BAC.PS.1 4017
# BAC.PW 2810
# BAC.PY 2810
# BAC.WA 1840
# BAC.WB 1893
# TFC.PG 2096
# TFC.PH 2751
# TFC.PI 3290
# TFC.PO 3402
# TFC.PR 3452
# TFX 34
# TGT 34
# TJX 34
# TMO 34
# TMUS 1626
# TMUSP 3311
# TPR 34
# TRGP 1024
# TRMB 34
# TROW 34
# TRV 34
# TSCO 34
# TSLA 912
# TSN 34
# TSNU 3336
# TT 34
# TTWO 34
# TXN 34
# TXT 34
# TXT.PA 3328
# TXT.PB 3330
# TYL 34
# UAL 34
# UDM 3598
# UDR 34
# UDR.PB 3971
# UDR.PG 2807
# UHID 36
# UHS 34
# ULTA 239
# UNH 34
# UNP 34
# UPS 34
# URI 34
# USB 34
# USB.PA 928
# USB.PH 34
# USB.PL 2757
# USB.PM 1559
# USB.PN 2815
# USB.PO 2129
# USB.PP 2955
# USB.PQ 3516
# USB.PR 3582
# USB.PS 3842
# V 338
# VFC 34
# VLO 34
# VMC 34
# VNO 34
# VNO.PE 2652
# VNO.PF 2529
# VNO.PG 1300
# VNO.PH 2529
# VNO.PI 1295
# VNO.PJ 2722
# VNO.PK 1743
# VNO.PL 1556
# VNO.PM 2784
# VNO.PN 3531
# VNO.PO 3734
# VNO.WI 4063
# VNORP 66
# VRSK 730
# VRSN 34
# VRTX 34
# VTR 34
# VTRS 34
# VZ 34
# WAB 34
# WAT 34
# WBA 34
# WBD 34
# WDC 34
# WEC 34
# WELL 34
# WELL.PI 2060
# WFC 34
# WFC.PA 3510
# WFC.PC 3580
# WFC.PD 3702
# WFC.PJ 1368
# WFC.PL 356
# WFC.PN 1851
# WFC.PO 1850
# WFC.PP 2060
# WFC.PQ 1683
# WFC.PR 1786
# WFC.PT 2455
# WFC.PV 2745
# WFC.PW 2775
# WFC.PX 2745
# WFC.PY 2624
# WFC.PZ 3316
# WFC.WS 1948
# WHR 34
# WM 34
# WMB 34
# WMT 34
# WRB 34
# WRB.PE 2864
# WRB.PF 3298
# WST 34
# WTW 34
# WY 34
# WY.PA 3307
# WYNN 34
# XCJ 2730
# XEL 34
# XEL.PA 2854
# XEL.PB 2854
# XEL.PC 2854
# XEL.PD 2854
# XEL.PE 2854
# XEL.PG 2854
# XGM 2992
# XOM 34
# XRAY 34
# XYL 1239
# YUM 34
# ZB.PC 2777
# ZB.PE 3569
# ZB.PF 2784
# ZBH 34
# ZBH.WI 4066
# ZBRA 34
# ZION 34
# ZIONN 2027
# ZIONO 1566
# ZIONP 34
# ZIONW 1551
# ZIONZ 2570

# %%
volume_stock_data_clean_pivot= volume_stock_data_clean_pivot[start:end][used_ticker_symbols]

# %%
list_of_missing = []
for col in volume_stock_data_clean_pivot.columns:
    list_of_missing.append((str(col), volume_stock_data_clean_pivot[col].isnull().sum()))

# %%
print(list_of_missing)
# Out:
), ('GRMN', 0), ('GS', 0), ('GWW', 0), ('HAL', 0), ('HAS', 0), ('HBAN', 0), ('HCA', 0), ('HD', 0), ('HES', 0), ('HIG', 0), ('HII', 0), ('HOLX', 0), ('HON', 0), ('HPQ', 0), ('HRL', 0), ('HSIC', 0), ('HST', 0), ('HSY', 0), ('HUM', 0), ('IBM', 0), ('ICE', 0), ('IDXX', 0), ('IEX', 0), ('IFF', 0), ('ILMN', 0), ('INCY', 0), ('INTC', 0), ('INTU', 0), ('IP', 0), ('IPG', 0), ('IRM', 0), ('ISRG', 0), ('IT', 0), ('ITW', 0), ('IVZ', 0), ('J', 0), ('JBHT', 0), ('JCI', 0), ('JKHY', 0), ('JNJ', 0), ('JNPR', 0), ('JPM', 0), ('K', 0), ('KDP', 0), ('KEY', 0), ('KIM', 0), ('KLAC', 0), ('KMB', 0), ('KMI', 0), ('KMX', 0), ('KO', 0), ('KR', 0), ('L', 0), ('LDOS', 0), ('LEN', 0), ('LH', 0), ('LHX', 0), ('LIN', 0), ('LKQ', 0), ('LLY', 0), ('LMT', 0), ('LNC', 0), ('LNT', 0), ('LOW', 0), ('LRCX', 0), ('LUMN', 0), ('LUV', 0), ('LVS', 0), ('LYB', 0), ('LYV', 0), ('MA', 0), ('MAA', 0), ('MAR', 0), ('MAS', 0), ('MCD', 0), ('MCHP', 0), ('MCK', 0), ('MCO', 0), ('MDLZ', 0), ('MDT', 0), ('MET', 0), ('META', 0), ('MGM', 0), ('MHK', 0), ('MKC', 0), ('MKTX', 0), ('MLM', 0), ('MMC', 0), ('MMM', 0), ('MNST', 0), ('MO', 0), ('MOH', 0), ('MOS', 0), ('MPC', 0), ('MPWR', 0), ('MRK', 0), ('MRO', 0), ('MS', 0), ('MSCI', 0), ('MSFT', 0), ('MSI', 0), ('MTB', 0), ('MTCH', 0), ('MTD', 0), ('MU', 0), ('NDAQ', 0), ('NDSN', 0), ('NEE', 0), ('NEM', 0), ('NFLX', 0), ('NI', 0), ('NKE', 0), ('NOC', 0), ('NOW', 0), ('NRG', 0), ('NSC', 0), ('NTAP', 0), ('NTRS', 0), ('NUE', 0), ('NVDA', 0), ('NVR', 0), ('NWL', 0), ('NXPI', 0), ('O', 0), ('ODFL', 0), ('OKE', 0), ('OMC', 0), ('ON', 0), ('ORCL', 0), ('ORLY', 0), ('OXY', 0), ('PARA', 0), ('PAYX', 0), ('PCAR', 0), ('PCG', 0), ('PEAK', 0), ('PEG', 0), ('PEP ...

# %%
sorted(list_of_missing, key= lambda x: x[1], reverse=True)
# Out:
# [('A', 0),
#  ('AAL', 0),
#  ('AAP', 0),
#  ('AAPL', 0),
#  ('ABBV', 0),
#  ('ABC', 0),
#  ('ABT', 0),
#  ('ACGL', 0),
#  ('ACN', 0),
#  ('ADBE', 0),
#  ('ADI', 0),
#  ('ADM', 0),
#  ('ADP', 0),
#  ('ADSK', 0),
#  ('AEE', 0),
#  ('AEP', 0),
#  ('AES', 0),
#  ('AFL', 0),
#  ('AIG', 0),
#  ('AIZ', 0),
#  ('AJG', 0),
#  ('AKAM', 0),
#  ('ALB', 0),
#  ('ALGN', 0),
#  ('ALK', 0),
#  ('ALL', 0),
#  ('AMAT', 0),
#  ('AMCR', 0),
#  ('AMD', 0),
#  ('AME', 0),
#  ('AMGN', 0),
#  ('AMP', 0),
#  ('AMT', 0),
#  ('AMZN', 0),
#  ('ANSS', 0),
#  ('AON', 0),
#  ('AOS', 0),
#  ('APA', 0),
#  ('APD', 0),
#  ('APH', 0),
#  ('APTV', 0),
#  ('ARE', 0),
#  ('ATO', 0),
#  ('ATVI', 0),
#  ('AVB', 0),
#  ('AVGO', 0),
#  ('AVY', 0),
#  ('AWK', 0),
#  ('AXP', 0),
#  ('AZO', 0),
#  ('BA', 0),
#  ('BAC', 0),
#  ('BALL', 0),
#  ('BAX', 0),
#  ('BBWI', 0),
#  ('BBY', 0),
#  ('BDX', 0),
#  ('BEN', 0),
#  ('BIIB', 0),
#  ('BIO', 0),
#  ('BK', 0),
#  ('BKNG', 0),
#  ('BKR', 0),
#  ('BLK', 0),
#  ('BMY', 0),
#  ('BR', 0),
#  ('BRO', 0),
#  ('BSX', 0),
#  ('BWA', 0),
#  ('BXP', 0),
#  ('C', 0),
#  ('CAG', 0),
#  ('CAH', 0),
#  ('CAT', 0),
#  ('CB', 0),
#  ('CBOE', 0),
#  ('CBRE', 0),
#  ('CCI', 0),
#  ('CCL', 0),
#  ('CDNS', 0),
#  ('CE', 0),
#  ('CF', 0),
#  ('CHD', 0),
#  ('CHRW', 0),
#  ('CHTR', 0),
#  ('CI', 0),
#  ('CINF', 0),
#  ('CL', 0),
#  ('CLX', 0),
#  ('CMA', 0),
#  ('CMCSA', 0),
#  ('CME', 0),
#  ('CMG', 0),
#  ('CMI', 0),
#  ('CMS', 0),
#  ('CNC', 0),
#  ('CNP', 0),
#  ('COF', 0),
#  ('COO', 0),
#  ('COP', 0),
#  ('COST', 0),
#  ('CPB', 0),
#  ('CPRT', 0),
#  ('CPT', 0),
#  ('CRL', 0),
#  ('CRM', 0),
#  ('CSCO', 0),
#  ('CSGP', 0),
#  ('CSX', 0),
#  ('CTAS', 0),
#  ('CTRA', 0),
#  ('CTSH', 0),
#  ('CVS', 0),
#  ('CVX', 0),
#  ('D', 0),
#  ('DAL', 0),
#  ('DD', 0),
#  ('DE', 0),
#  ('DFS', 0),
#  ('DG', 0),
#  ('DGX', 0),
#  ('DHI', 0),
#  ('DHR', 0),
#  ('DIS', 0),
#  ('DISH', 0),
#  ('DLR', 0),
#  ('DLTR', 0),
#  ('DOV', 0),
#  ('DPZ', 0),
#  ('DRI', 0),
#  ('DTE', 0),
#  ('DUK', 0),
#  ('DVA', 0),
#  ('DVN', 0),
#  ('DXC', 0),
#  ('DXCM', 0),
#  ('EA', 0),
#  ('EBAY', 0),
#  ('ECL', 0),
#  ('ED', 0),
#  ('EFX', 0),
#  ('EIX', 0),
#  ('EL', 0),
#  ('ELV', 0),
#  ('EMN', 0),
#  ('EMR', 0),
#  ('ENPH', 0),
#  ('EOG', 0),
#  ('EPAM', 0),
#  ('EQIX', 0),
#  ('EQR', 0),
#  ('EQT', 0),
#  ('ES', 0),
#  ('ESS', 0),
#  ('ETN', 0),
#  ('ETR', 0),
#  ('EVRG', 0),
#  ('EW', 0),
#  ('EXC', 0),
#  ('EXPD', 0),
#  ('EXPE', 0),
#  ('EXR', 0),
#  ('F', 0),
#  ('FANG', 0),
#  ('FAST', 0),
#  ('FCX', 0),
#  ('FDS', 0),
#  ('FDX', 0),
#  ('FE', 0),
#  ('FFIV', 0),
#  ('FIS', 0),
#  ('FISV', 0),
#  ('FITB', 0),
#  ('FLT', 0),
#  ('FMC', 0),
#  ('FRC', 0),
#  ('FRT', 0),
#  ('FSLR', 0),
#  ('FTNT', 0),
#  ('GD', 0),
#  ('GE', 0),
#  ('GEN', 0),
#  ('GILD', 0),
#  ('GIS', 0),
#  ('GL', 0),
#  ('GLW', 0),
#  ('GM', 0),
#  ('GNRC', 0),
#  ('GOOG', 0),
#  ('GOOGL', 0),
#  ('GPC', 0),
#  ('GPN', 0),
#  ('GRMN', 0),
#  ('GS', 0),
#  ('GWW', 0),
#  ('HAL', 0),
#  ('HAS', 0),
#  ('HBAN', 0),
#  ('HCA', 0),
#  ('HD', 0),
#  ('HES', 0),
#  ('HIG', 0),
#  ('HII', 0),
#  ('HOLX', 0),
#  ('HON', 0),
#  ('HPQ', 0),
#  ('HRL', 0),
#  ('HSIC', 0),
#  ('HST', 0),
#  ('HSY', 0),
#  ('HUM', 0),
#  ('IBM', 0),
#  ('ICE', 0),
#  ('IDXX', 0),
#  ('IEX', 0),
#  ('IFF', 0),
#  ('ILMN', 0),
#  ('INCY', 0),
#  ('INTC', 0),
#  ('INTU', 0),
#  ('IP', 0),
#  ('IPG', 0),
#  ('IRM', 0),
#  ('ISRG', 0),
#  ('IT', 0),
#  ('ITW', 0),
#  ('IVZ', 0),
#  ('J', 0),
#  ('JBHT', 0),
#  ('JCI', 0),
#  ('JKHY', 0),
#  ('JNJ', 0),
#  ('JNPR', 0),
#  ('JPM', 0),
#  ('K', 0),
#  ('KDP', 0),
#  ('KEY', 0),
#  ('KIM', 0),
#  ('KLAC', 0),
#  ('KMB', 0),
#  ('KMI', 0),
#  ('KMX', 0),
#  ('KO', 0),
#  ('KR', 0),
#  ('L', 0),
#  ('LDOS', 0),
#  ('LEN', 0),
#  ('LH', 0),
#  ('LHX', 0),
#  ('LIN', 0),
#  ('LKQ', 0),
#  ('LLY', 0),
#  ('LMT', 0),
#  ('LNC', 0),
#  ('LNT', 0),
#  ('LOW', 0),
#  ('LRCX', 0),
#  ('LUMN', 0),
#  ('LUV', 0),
#  ('LVS', 0),
#  ('LYB', 0),
#  ('LYV', 0),
#  ('MA', 0),
#  ('MAA', 0),
#  ('MAR', 0),
#  ('MAS', 0),
#  ('MCD', 0),
#  ('MCHP', 0),
#  ('MCK', 0),
#  ('MCO', 0),
#  ('MDLZ', 0),
#  ('MDT', 0),
#  ('MET', 0),
#  ('META', 0),
#  ('MGM', 0),
#  ('MHK', 0),
#  ('MKC', 0),
#  ('MKTX', 0),
#  ('MLM', 0),
#  ('MMC', 0),
#  ('MMM', 0),
#  ('MNST', 0),
#  ('MO', 0),
#  ('MOH', 0),
#  ('MOS', 0),
#  ('MPC', 0),
#  ('MPWR', 0),
#  ('MRK', 0),
#  ('MRO', 0),
#  ('MS', 0),
#  ('MSCI', 0),
#  ('MSFT', 0),
#  ('MSI', 0),
#  ('MTB', 0),
#  ('MTCH', 0),
#  ('MTD', 0),
#  ('MU', 0),
#  ('NDAQ', 0),
#  ('NDSN', 0),
#  ('NEE', 0),
#  ('NEM', 0),
#  ('NFLX', 0),
#  ('NI', 0),
#  ('NKE', 0),
#  ('NOC', 0),
#  ('NOW', 0),
#  ('NRG', 0),
#  ('NSC', 0),
#  ('NTAP', 0),
#  ('NTRS', 0),
#  ('NUE', 0),
#  ('NVDA', 0),
#  ('NVR', 0),
#  ('NWL', 0),
#  ('NXPI', 0),
#  ('O', 0),
#  ('ODFL', 0),
#  ('OKE', 0),
#  ('OMC', 0),
#  ('ON', 0),
#  ('ORCL', 0),
#  ('ORLY', 0),
#  ('OXY', 0),
#  ('PARA', 0),
#  ('PAYX', 0),
#  ('PCAR', 0),
#  ('PCG', 0),
#  ('PEAK', 0),
#  ('PEG', 0),
#  ('PEP', 0),
#  ('PFE', 0),
#  ('PFG', 0),
#  ('PG', 0),
#  ('PGR', 0),
#  ('PH', 0),
#  ('PHM', 0),
#  ('PKG', 0),
#  ('PKI', 0),
#  ('PLD', 0),
#  ('PM', 0),
#  ('PNC', 0),
#  ('PNR', 0),
#  ('PNW', 0),
#  ('POOL', 0),
#  ('PPG', 0),
#  ('PPL', 0),
#  ('PRU', 0),
#  ('PSA', 0),
#  ('PSX', 0),
#  ('PTC', 0),
#  ('PWR', 0),
#  ('PXD', 0),
#  ('QCOM', 0),
#  ('RCL', 0),
#  ('RE', 0),
#  ('REG', 0),
#  ('REGN', 0),
#  ('RF', 0),
#  ('RHI', 0),
#  ('RJF', 0),
#  ('RL', 0),
#  ('RMD', 0),
#  ('ROK', 0),
#  ('ROL', 0),
#  ('ROP', 0),
#  ('ROST', 0),
#  ('RSG', 0),
#  ('RTX', 0),
#  ('SBAC', 0),
#  ('SBNY', 0),
#  ('SBUX', 0),
#  ('SCHW', 0),
#  ('SEE', 0),
#  ('SHW', 0),
#  ('SIVB', 0),
#  ('SJM', 0),
#  ('SLB', 0),
#  ('SNA', 0),
#  ('SNPS', 0),
#  ('SO', 0),
#  ('SPG', 0),
#  ('SPGI', 0),
#  ('SRE', 0),
#  ('STE', 0),
#  ('STLD', 0),
#  ('STT', 0),
#  ('STX', 0),
#  ('STZ', 0),
#  ('SWK', 0),
#  ('SWKS', 0),
#  ('SYK', 0),
#  ('SYY', 0),
#  ('T', 0),
#  ('TAP', 0),
#  ('TDG', 0),
#  ('TDY', 0),
#  ('TECH', 0),
#  ('TEL', 0),
#  ('TER', 0),
#  ('TFC', 0),
#  ('TFX', 0),
#  ('TGT', 0),
#  ('TJX', 0),
#  ('TMO', 0),
#  ('TMUS', 0),
#  ('TPR', 0),
#  ('TRGP', 0),
#  ('TRMB', 0),
#  ('TROW', 0),
#  ('TRV', 0),
#  ('TSCO', 0),
#  ('TSLA', 0),
#  ('TSN', 0),
#  ('TT', 0),
#  ('TTWO', 0),
#  ('TXN', 0),
#  ('TXT', 0),
#  ('TYL', 0),
#  ('UAL', 0),
#  ('UDR', 0),
#  ('UHS', 0),
#  ('ULTA', 0),
#  ('UNH', 0),
#  ('UNP', 0),
#  ('UPS', 0),
#  ('URI', 0),
#  ('USB', 0),
#  ('V', 0),
#  ('VFC', 0),
#  ('VLO', 0),
#  ('VMC', 0),
#  ('VNO', 0),
#  ('VRSK', 0),
#  ('VRSN', 0),
#  ('VRTX', 0),
#  ('VTR', 0),
#  ('VTRS', 0),
#  ('VZ', 0),
#  ('WAB', 0),
#  ('WAT', 0),
#  ('WBA', 0),
#  ('WBD', 0),
#  ('WDC', 0),
#  ('WEC', 0),
#  ('WELL', 0),
#  ('WFC', 0),
#  ('WHR', 0),
#  ('WM', 0),
#  ('WMB', 0),
#  ('WMT', 0),
#  ('WRB', 0),
#  ('WST', 0),
#  ('WTW', 0),
#  ('WY', 0),
#  ('WYNN', 0),
#  ('XEL', 0),
#  ('XOM', 0),
#  ('XRAY', 0),
#  ('XYL', 0),
#  ('YUM', 0),
#  ('ZBH', 0),
#  ('ZBRA', 0),
#  ('ZION', 0)]

# %%
list_of_missing
# Out:
# [('A', 0),
#  ('AAL', 0),
#  ('AAP', 0),
#  ('AAPL', 0),
#  ('ABBV', 0),
#  ('ABC', 0),
#  ('ABT', 0),
#  ('ACGL', 0),
#  ('ACN', 0),
#  ('ADBE', 0),
#  ('ADI', 0),
#  ('ADM', 0),
#  ('ADP', 0),
#  ('ADSK', 0),
#  ('AEE', 0),
#  ('AEP', 0),
#  ('AES', 0),
#  ('AFL', 0),
#  ('AIG', 0),
#  ('AIZ', 0),
#  ('AJG', 0),
#  ('AKAM', 0),
#  ('ALB', 0),
#  ('ALGN', 0),
#  ('ALK', 0),
#  ('ALL', 0),
#  ('AMAT', 0),
#  ('AMCR', 0),
#  ('AMD', 0),
#  ('AME', 0),
#  ('AMGN', 0),
#  ('AMP', 0),
#  ('AMT', 0),
#  ('AMZN', 0),
#  ('ANSS', 0),
#  ('AON', 0),
#  ('AOS', 0),
#  ('APA', 0),
#  ('APD', 0),
#  ('APH', 0),
#  ('APTV', 0),
#  ('ARE', 0),
#  ('ATO', 0),
#  ('ATVI', 0),
#  ('AVB', 0),
#  ('AVGO', 0),
#  ('AVY', 0),
#  ('AWK', 0),
#  ('AXP', 0),
#  ('AZO', 0),
#  ('BA', 0),
#  ('BAC', 0),
#  ('BALL', 0),
#  ('BAX', 0),
#  ('BBWI', 0),
#  ('BBY', 0),
#  ('BDX', 0),
#  ('BEN', 0),
#  ('BIIB', 0),
#  ('BIO', 0),
#  ('BK', 0),
#  ('BKNG', 0),
#  ('BKR', 0),
#  ('BLK', 0),
#  ('BMY', 0),
#  ('BR', 0),
#  ('BRO', 0),
#  ('BSX', 0),
#  ('BWA', 0),
#  ('BXP', 0),
#  ('C', 0),
#  ('CAG', 0),
#  ('CAH', 0),
#  ('CAT', 0),
#  ('CB', 0),
#  ('CBOE', 0),
#  ('CBRE', 0),
#  ('CCI', 0),
#  ('CCL', 0),
#  ('CDNS', 0),
#  ('CE', 0),
#  ('CF', 0),
#  ('CHD', 0),
#  ('CHRW', 0),
#  ('CHTR', 0),
#  ('CI', 0),
#  ('CINF', 0),
#  ('CL', 0),
#  ('CLX', 0),
#  ('CMA', 0),
#  ('CMCSA', 0),
#  ('CME', 0),
#  ('CMG', 0),
#  ('CMI', 0),
#  ('CMS', 0),
#  ('CNC', 0),
#  ('CNP', 0),
#  ('COF', 0),
#  ('COO', 0),
#  ('COP', 0),
#  ('COST', 0),
#  ('CPB', 0),
#  ('CPRT', 0),
#  ('CPT', 0),
#  ('CRL', 0),
#  ('CRM', 0),
#  ('CSCO', 0),
#  ('CSGP', 0),
#  ('CSX', 0),
#  ('CTAS', 0),
#  ('CTRA', 0),
#  ('CTSH', 0),
#  ('CVS', 0),
#  ('CVX', 0),
#  ('D', 0),
#  ('DAL', 0),
#  ('DD', 0),
#  ('DE', 0),
#  ('DFS', 0),
#  ('DG', 0),
#  ('DGX', 0),
#  ('DHI', 0),
#  ('DHR', 0),
#  ('DIS', 0),
#  ('DISH', 0),
#  ('DLR', 0),
#  ('DLTR', 0),
#  ('DOV', 0),
#  ('DPZ', 0),
#  ('DRI', 0),
#  ('DTE', 0),
#  ('DUK', 0),
#  ('DVA', 0),
#  ('DVN', 0),
#  ('DXC', 0),
#  ('DXCM', 0),
#  ('EA', 0),
#  ('EBAY', 0),
#  ('ECL', 0),
#  ('ED', 0),
#  ('EFX', 0),
#  ('EIX', 0),
#  ('EL', 0),
#  ('ELV', 0),
#  ('EMN', 0),
#  ('EMR', 0),
#  ('ENPH', 0),
#  ('EOG', 0),
#  ('EPAM', 0),
#  ('EQIX', 0),
#  ('EQR', 0),
#  ('EQT', 0),
#  ('ES', 0),
#  ('ESS', 0),
#  ('ETN', 0),
#  ('ETR', 0),
#  ('EVRG', 0),
#  ('EW', 0),
#  ('EXC', 0),
#  ('EXPD', 0),
#  ('EXPE', 0),
#  ('EXR', 0),
#  ('F', 0),
#  ('FANG', 0),
#  ('FAST', 0),
#  ('FCX', 0),
#  ('FDS', 0),
#  ('FDX', 0),
#  ('FE', 0),
#  ('FFIV', 0),
#  ('FIS', 0),
#  ('FISV', 0),
#  ('FITB', 0),
#  ('FLT', 0),
#  ('FMC', 0),
#  ('FRC', 0),
#  ('FRT', 0),
#  ('FSLR', 0),
#  ('FTNT', 0),
#  ('GD', 0),
#  ('GE', 0),
#  ('GEN', 0),
#  ('GILD', 0),
#  ('GIS', 0),
#  ('GL', 0),
#  ('GLW', 0),
#  ('GM', 0),
#  ('GNRC', 0),
#  ('GOOG', 0),
#  ('GOOGL', 0),
#  ('GPC', 0),
#  ('GPN', 0),
#  ('GRMN', 0),
#  ('GS', 0),
#  ('GWW', 0),
#  ('HAL', 0),
#  ('HAS', 0),
#  ('HBAN', 0),
#  ('HCA', 0),
#  ('HD', 0),
#  ('HES', 0),
#  ('HIG', 0),
#  ('HII', 0),
#  ('HOLX', 0),
#  ('HON', 0),
#  ('HPQ', 0),
#  ('HRL', 0),
#  ('HSIC', 0),
#  ('HST', 0),
#  ('HSY', 0),
#  ('HUM', 0),
#  ('IBM', 0),
#  ('ICE', 0),
#  ('IDXX', 0),
#  ('IEX', 0),
#  ('IFF', 0),
#  ('ILMN', 0),
#  ('INCY', 0),
#  ('INTC', 0),
#  ('INTU', 0),
#  ('IP', 0),
#  ('IPG', 0),
#  ('IRM', 0),
#  ('ISRG', 0),
#  ('IT', 0),
#  ('ITW', 0),
#  ('IVZ', 0),
#  ('J', 0),
#  ('JBHT', 0),
#  ('JCI', 0),
#  ('JKHY', 0),
#  ('JNJ', 0),
#  ('JNPR', 0),
#  ('JPM', 0),
#  ('K', 0),
#  ('KDP', 0),
#  ('KEY', 0),
#  ('KIM', 0),
#  ('KLAC', 0),
#  ('KMB', 0),
#  ('KMI', 0),
#  ('KMX', 0),
#  ('KO', 0),
#  ('KR', 0),
#  ('L', 0),
#  ('LDOS', 0),
#  ('LEN', 0),
#  ('LH', 0),
#  ('LHX', 0),
#  ('LIN', 0),
#  ('LKQ', 0),
#  ('LLY', 0),
#  ('LMT', 0),
#  ('LNC', 0),
#  ('LNT', 0),
#  ('LOW', 0),
#  ('LRCX', 0),
#  ('LUMN', 0),
#  ('LUV', 0),
#  ('LVS', 0),
#  ('LYB', 0),
#  ('LYV', 0),
#  ('MA', 0),
#  ('MAA', 0),
#  ('MAR', 0),
#  ('MAS', 0),
#  ('MCD', 0),
#  ('MCHP', 0),
#  ('MCK', 0),
#  ('MCO', 0),
#  ('MDLZ', 0),
#  ('MDT', 0),
#  ('MET', 0),
#  ('META', 0),
#  ('MGM', 0),
#  ('MHK', 0),
#  ('MKC', 0),
#  ('MKTX', 0),
#  ('MLM', 0),
#  ('MMC', 0),
#  ('MMM', 0),
#  ('MNST', 0),
#  ('MO', 0),
#  ('MOH', 0),
#  ('MOS', 0),
#  ('MPC', 0),
#  ('MPWR', 0),
#  ('MRK', 0),
#  ('MRO', 0),
#  ('MS', 0),
#  ('MSCI', 0),
#  ('MSFT', 0),
#  ('MSI', 0),
#  ('MTB', 0),
#  ('MTCH', 0),
#  ('MTD', 0),
#  ('MU', 0),
#  ('NDAQ', 0),
#  ('NDSN', 0),
#  ('NEE', 0),
#  ('NEM', 0),
#  ('NFLX', 0),
#  ('NI', 0),
#  ('NKE', 0),
#  ('NOC', 0),
#  ('NOW', 0),
#  ('NRG', 0),
#  ('NSC', 0),
#  ('NTAP', 0),
#  ('NTRS', 0),
#  ('NUE', 0),
#  ('NVDA', 0),
#  ('NVR', 0),
#  ('NWL', 0),
#  ('NXPI', 0),
#  ('O', 0),
#  ('ODFL', 0),
#  ('OKE', 0),
#  ('OMC', 0),
#  ('ON', 0),
#  ('ORCL', 0),
#  ('ORLY', 0),
#  ('OXY', 0),
#  ('PARA', 0),
#  ('PAYX', 0),
#  ('PCAR', 0),
#  ('PCG', 0),
#  ('PEAK', 0),
#  ('PEG', 0),
#  ('PEP', 0),
#  ('PFE', 0),
#  ('PFG', 0),
#  ('PG', 0),
#  ('PGR', 0),
#  ('PH', 0),
#  ('PHM', 0),
#  ('PKG', 0),
#  ('PKI', 0),
#  ('PLD', 0),
#  ('PM', 0),
#  ('PNC', 0),
#  ('PNR', 0),
#  ('PNW', 0),
#  ('POOL', 0),
#  ('PPG', 0),
#  ('PPL', 0),
#  ('PRU', 0),
#  ('PSA', 0),
#  ('PSX', 0),
#  ('PTC', 0),
#  ('PWR', 0),
#  ('PXD', 0),
#  ('QCOM', 0),
#  ('RCL', 0),
#  ('RE', 0),
#  ('REG', 0),
#  ('REGN', 0),
#  ('RF', 0),
#  ('RHI', 0),
#  ('RJF', 0),
#  ('RL', 0),
#  ('RMD', 0),
#  ('ROK', 0),
#  ('ROL', 0),
#  ('ROP', 0),
#  ('ROST', 0),
#  ('RSG', 0),
#  ('RTX', 0),
#  ('SBAC', 0),
#  ('SBNY', 0),
#  ('SBUX', 0),
#  ('SCHW', 0),
#  ('SEE', 0),
#  ('SHW', 0),
#  ('SIVB', 0),
#  ('SJM', 0),
#  ('SLB', 0),
#  ('SNA', 0),
#  ('SNPS', 0),
#  ('SO', 0),
#  ('SPG', 0),
#  ('SPGI', 0),
#  ('SRE', 0),
#  ('STE', 0),
#  ('STLD', 0),
#  ('STT', 0),
#  ('STX', 0),
#  ('STZ', 0),
#  ('SWK', 0),
#  ('SWKS', 0),
#  ('SYK', 0),
#  ('SYY', 0),
#  ('T', 0),
#  ('TAP', 0),
#  ('TDG', 0),
#  ('TDY', 0),
#  ('TECH', 0),
#  ('TEL', 0),
#  ('TER', 0),
#  ('TFC', 0),
#  ('TFX', 0),
#  ('TGT', 0),
#  ('TJX', 0),
#  ('TMO', 0),
#  ('TMUS', 0),
#  ('TPR', 0),
#  ('TRGP', 0),
#  ('TRMB', 0),
#  ('TROW', 0),
#  ('TRV', 0),
#  ('TSCO', 0),
#  ('TSLA', 0),
#  ('TSN', 0),
#  ('TT', 0),
#  ('TTWO', 0),
#  ('TXN', 0),
#  ('TXT', 0),
#  ('TYL', 0),
#  ('UAL', 0),
#  ('UDR', 0),
#  ('UHS', 0),
#  ('ULTA', 0),
#  ('UNH', 0),
#  ('UNP', 0),
#  ('UPS', 0),
#  ('URI', 0),
#  ('USB', 0),
#  ('V', 0),
#  ('VFC', 0),
#  ('VLO', 0),
#  ('VMC', 0),
#  ('VNO', 0),
#  ('VRSK', 0),
#  ('VRSN', 0),
#  ('VRTX', 0),
#  ('VTR', 0),
#  ('VTRS', 0),
#  ('VZ', 0),
#  ('WAB', 0),
#  ('WAT', 0),
#  ('WBA', 0),
#  ('WBD', 0),
#  ('WDC', 0),
#  ('WEC', 0),
#  ('WELL', 0),
#  ('WFC', 0),
#  ('WHR', 0),
#  ('WM', 0),
#  ('WMB', 0),
#  ('WMT', 0),
#  ('WRB', 0),
#  ('WST', 0),
#  ('WTW', 0),
#  ('WY', 0),
#  ('WYNN', 0),
#  ('XEL', 0),
#  ('XOM', 0),
#  ('XRAY', 0),
#  ('XYL', 0),
#  ('YUM', 0),
#  ('ZBH', 0),
#  ('ZBRA', 0),
# 2022-12-27  2265992.0  4024281.0  1580610.0  11874640.0   998778.0   468173.0
# 2022-12-28  2244112.0  2131050.0  1513689.0  10675270.0  1430535.0   480378.0
# 2022-12-29  1845747.0  1431045.0  1398037.0  10526150.0  1139467.0   516306.0
# 2022-12-30  3166563.0  1613718.0  1597003.0  11790980.0  1352751.0   548889.0
#
# tic                YUM        ZBH      ZBRA       ZION
# Date
# 2013-01-02   4376855.0  1397462.0  213748.0  2551059.0
# 2013-01-03   2627253.0  1574966.0   99849.0  2267804.0
# 2013-01-04   2719375.0  1189537.0  145944.0  3577660.0
# 2013-01-07   3729703.0   954238.0   90581.0  2285917.0
# 2013-01-08  12406140.0   905965.0  112590.0  3758558.0
# ...                ...        ...       ...        ...
# 2022-12-23    699735.0   789770.0  180932.0  1263345.0
# 2022-12-27   1299183.0   742499.0  252510.0   704184.0
# 2022-12-28    964755.0   750108.0  241209.0   679957.0
# 2022-12-29    875749.0   686569.0  274913.0   685349.0
# 2022-12-30   1401328.0   785116.0  228188.0   609715.0
#
# [2539 rows x 463 columns]

# %%
# Out:
# Index(['datadate', '2007/01/03', '2007/01/04', '2007/01/05', '2007/01/08',
#        '2007/01/09', '2007/01/10', '2007/01/11', '2007/01/12', '2007/01/16',
#        ...
#        '2010/11/22', '2010/11/23', '2010/11/24', '2010/11/26', '2010/11/29',
#        '2010/11/30', '2010/12/01', '2010/12/02', '2010/12/03', '2010/12/06'],
#       dtype='object', name=2, length=2440296)

# %%
# reference: Wharton Research Data Services. "WRDS" wrds.wharton.upenn.edu, accessed 2023-01-16.

# %%
# Plotting mean (adj close) daily returns, averaged per day across all stocks:
df_clean_daily_returns.mean(1).plot(title='Mean Daily Returns across all stocks')
# Out:
# <div>                            <div id="561cdda1-afc3-4738-a301-c9795847bd0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("561cdda1-afc3-4738-a301-c9795847bd0f")) {                    Plotly.newPlot(                        "561cdda1-afc3-4738-a301-c9795847bd0f",                        [{"hovertemplate":"variable=0<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","showlegend":true,"x":["2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-03T00:00:00","2013-06-04T00:00:00","2013-06-05T00:00:00","2013-06-06T00:00:00","2013-06-07T00:00:00","2013-06-10T00:00:00","2013-06-11T00:00:00","2013-06-12T00:00:00","2013-06-13T00:00:00","2013-06-14T00:00:00","2013-06-17T00:00:00","2013-06-18T00:00:00","2013-06-19T00:00:00","2013-06-20T00:00:00","2013-06-21T00:00:00","2013-06-24T00:00:00","2013-06-25T00:00:00","2013-06-26T00:00:00","2013-06-27T00:00:00","2013-06-28T00:00:00","2013-07-01T00:00:00","2013-07-02T00:00:00","2013-07-03T00:00:00","2013-07-05T00:00:00","2013-07-08T00:00:00","2013-07-09T00:00:00","2013-07-10T00:00:00","2013-07-11T00:00:00","2013-07-12T00:00:00","2013-07-15T00:00:00","2013-07-16T00:00:00","2013-07-17T00:00:00","2013-07-18T00:00:00","2013-07-19T00:00:00","2013-07-22T00:00:00","2013-07-23T00:00:00","2013-07-24T00:00:00","2013-07-25T00:00:00","2013-07-26T00:00:00","2013-07-29T00:00:00","2013-07-30T00:00:00","2013-07-31T00:00:00","2013-08-01T00:00:00","2013-08-02T00:00:00","2013-08-05T00:00:00","20 ...

# %%
# Plotting mean daily volume, averaged per day across all stocks:
df_volume_clean.mean(1).plot(title='Mean Daily Volume across all stocks')
# Out:
# <div>                            <div id="45aefa76-6bd8-4947-aa53-f56c2bb20288" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45aefa76-6bd8-4947-aa53-f56c2bb20288")) {                    Plotly.newPlot(                        "45aefa76-6bd8-4947-aa53-f56c2bb20288",                        [{"hovertemplate":"variable=0<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","showlegend":true,"x":["2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-03T00:00:00","2013-06-04T00:00:00","2013-06-05T00:00:00","2013-06-06T00:00:00","2013-06-07T00:00:00","2013-06-10T00:00:00","2013-06-11T00:00:00","2013-06-12T00:00:00","2013-06-13T00:00:00","2013-06-14T00:00:00","2013-06-17T00:00:00","2013-06-18T00:00:00","2013-06-19T00:00:00","2013-06-20T00:00:00","2013-06-21T00:00:00","2013-06-24T00:00:00","2013-06-25T00:00:00","2013-06-26T00:00:00","2013-06-27T00:00:00","2013-06-28T00:00:00","2013-07-01T00:00:00","2013-07-02T00:00:00","2013-07-03T00:00:00","2013-07-05T00:00:00","2013-07-08T00:00:00","2013-07-09T00:00:00","2013-07-10T00:00:00","2013-07-11T00:00:00","2013-07-12T00:00:00","2013-07-15T00:00:00","2013-07-16T00:00:00","2013-07-17T00:00:00","2013-07-18T00:00:00","2013-07-19T00:00:00","2013-07-22T00:00:00","2013-07-23T00:00:00","2013-07-24T00:00:00","2013-07-25T00:00:00","2013-07-26T00:00:00","2013-07-29T00:00:00","2013-07-30T00:00:00","2013-07-31T00:00:00","2013-08-01T00:00:00","2013-08-02T00:00:00","20 ...

# %%
# Plotting Total daily volume, summed per day across all stocks:
df_volume_clean.sum(1).plot(title='Total Daily Volume across all stocks')
# Out:
# <div>                            <div id="cec371a3-6c2c-4a9e-9596-a713f70d9a10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cec371a3-6c2c-4a9e-9596-a713f70d9a10")) {                    Plotly.newPlot(                        "cec371a3-6c2c-4a9e-9596-a713f70d9a10",                        [{"hovertemplate":"variable=0<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","showlegend":true,"x":["2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-03T00:00:00","2013-06-04T00:00:00","2013-06-05T00:00:00","2013-06-06T00:00:00","2013-06-07T00:00:00","2013-06-10T00:00:00","2013-06-11T00:00:00","2013-06-12T00:00:00","2013-06-13T00:00:00","2013-06-14T00:00:00","2013-06-17T00:00:00","2013-06-18T00:00:00","2013-06-19T00:00:00","2013-06-20T00:00:00","2013-06-21T00:00:00","2013-06-24T00:00:00","2013-06-25T00:00:00","2013-06-26T00:00:00","2013-06-27T00:00:00","2013-06-28T00:00:00","2013-07-01T00:00:00","2013-07-02T00:00:00","2013-07-03T00:00:00","2013-07-05T00:00:00","2013-07-08T00:00:00","2013-07-09T00:00:00","2013-07-10T00:00:00","2013-07-11T00:00:00","2013-07-12T00:00:00","2013-07-15T00:00:00","2013-07-16T00:00:00","2013-07-17T00:00:00","2013-07-18T00:00:00","2013-07-19T00:00:00","2013-07-22T00:00:00","2013-07-23T00:00:00","2013-07-24T00:00:00","2013-07-25T00:00:00","2013-07-26T00:00:00","2013-07-29T00:00:00","2013-07-30T00:00:00","2013-07-31T00:00:00","2013-08-01T00:00:00","2013-08-02T00:00:00","20 ...

# %% [markdown]
# # Getting stock volume data using WRDS plugin:
#
# conn = wrds.Connection(wrds_username='nitainijholt')

# %%
# saving the dataframes to csv files
df_clean_daily_returns.to_csv('data/df_clean_daily_returns.csv')
df_volume_clean.to_csv('data/df_volume_clean.csv')
df_shares_outstanding.to_csv('data/df_volume_clean.csv')

# %% [markdown]
# # Code below is unused so far

# %% [markdown]
# # Making a DataFrame containing Daily volume

# %%
df['Volume'].columns
# Out:
# Index(['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABT', 'ACGL', 'ACN', 'ADBE',
#        ...
#        'WYNN', 'XEL', 'XOM', 'XRAY', 'XYL', 'YUM', 'ZBH', 'ZBRA', 'ZION',
#        'ZTS'],
#       dtype='object', length=503)

# %%
col_with_missing_values = {}
for col in df['Volume'].columns:
    sum_of_missing_values = df['Adj Close'][col].isnull().sum()
    if sum_of_missing_values > 0:
        col_with_missing_values[col] = sum_of_missing_values
        print(col)
# Out:
# ALLE
# ANET
# BF.B
# BRK.B
# CARR
# CDAY
# CDW
# CEG
# CFG
# CTLT
# CTVA
# CZR
# DOW
# ETSY
# FOX
# FOXA
# FTV
# HLT
# HPE
# HWM
# INVH
# IQV
# IR
# KEYS
# KHC
# LW
# MRNA
# NCLH
# NWS
# NWSA
# OGN
# OTIS
# PAYC
# PYPL
# QRVO
# SEDG
# SYF
# VICI
# WRK
# ZTS

# %% [markdown]
# ## Acessing attributes of dataframe

# %%
close = df.Close

# %%
close[close.index > end - dt.timedelta(days=100)].describe()
# Out:
#                 A        AAL         AAP        AAPL        ABBV         ABC  \
# count   68.000000  68.000000   68.000000   68.000000   68.000000   68.000000
# mean   141.275000  13.461912  161.760147  143.183087  152.418089  156.387354
# std     11.258239   0.815157   15.984451    6.673953    9.121142   11.898258
# min    121.550003  11.860000  139.380005  126.040001  134.210007  135.330002
# 25%    131.987495  12.727500  146.934998  138.910000  144.417500  142.935005
# 50%    144.790001  13.650000  159.485001  143.805000  151.805000  158.555000
# 75%    150.880001  14.102500  174.884998  148.287498  161.615002  167.177498
# max    157.660004  14.930000  190.669998  155.740005  165.990005  173.990005
#
#               ABT       ACGL         ACN        ADBE  ...       WYNN  \
# count   68.000000  68.000000   68.000000   68.000000  ...  68.000000
# mean   103.165441  54.966765  275.259706  316.742792  ...  72.613823
# std      4.260518   6.262076   14.522118   22.157599  ...  10.343927
# min     95.059998  41.669998  250.070007  275.200012  ...  54.480000
# 25%     99.482498  48.537499  262.894997  296.777504  ...  64.297499
# 50%    103.449997  57.010000  273.380005  326.179993  ...  74.254997
# 75%    106.912502  60.010000  288.087509  336.522491  ...  81.787498
# max    111.529999  63.619999  302.829987  345.959991  ...  86.669998
#
#              XEL         XOM       XRAY         XYL         YUM         ZBH  \
# count  68.000000   68.000000  68.000000   68.000000   68.000000   68.000000
# mean   66.590735  105.655882  30.081324  103.628971  120.136470  115.295441
# std     3.823638    7.284724   1.282007    9.611404    8.740005    7.909126
# min    57.939999   83.980003  26.830000   86.199997  105.250000  104.550003
# 25%    64.247501  103.170000  29.172500   93.080000  110.884998  108.012503
# 50%    67.904999  106.994999  30.295000  108.605003  122.684998  113.329998
# 75%    69.674997  110.802502  30.980000  111.257502  128.607498  123.559999
# max    71.599998  114.180000  32.279999  114.989998  131.220001  128.429993
#
#              ZBRA       ZION         ZTS
# count   68.000000  68.000000   68.000000
# mean   259.058235  50.205147  148.118677
# std     13.208136   2.208463    5.278865
# min    226.880005  45.740002  131.139999
# 25%    251.347496  48.414999  145.729996
# 50%    260.744995  50.375000  148.575005
# 75%    267.182503  51.835000  151.697498
# max    288.000000  55.389999  157.419998
#
# [8 rows x 503 columns]

# %% [markdown]
# ## Creating Moving Averages

# %%
df['MA20'] = df['Close'].rolling(window = 20, min_periods = 1).mean()
df['MA9'] = df['Close'].rolling(window = 9, min_periods = 1).mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df['MA20'] = df['Close'].rolling(window = 20, min_periods = 1).mean()
#       2 df['MA9'] = df['Close'].rolling(window = 9, min_periods = 1).mean()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_array(key, value)
#    3967 elif isinstance(value, DataFrame):
# -> 3968     self._set_item_frame_value(key, value)
#    3969 elif (
#    3970     is_list_like(value)
#    3971     and not self.columns.is_unique
#    3972     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3973 ):
#    3974     # Column to set is duplicated
#    3975     self._setitem_array([key], value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:4123, in DataFrame._set_item_frame_value(self, key, value)
#    4120     return
#    4122 if len(value.columns) != 1:
# -> 4123     raise ValueError(
#    4124         "Cannot set a DataFrame with multiple columns to the single "
#    4125         f"column {key}"
#    4126     )
#    4128 self[key] = value[value.columns[0]]
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column MA20

# %% [markdown]
# ## Plotting data

# %%
## https://www.youtube.com/watch?v=yQtT_4RgT2k
# fig = make_subplots(rows = 2, cols = 1, shared_xaxes= True, vertical_spacing = 0.1, subplot_titles = ('QQQ', 'Volume'),
#                     row_width = [0.2, 0.7])
# fig.add_trace(go.Candlestick(x=df.index, open=df["Open"], high=df["High"],
#                 low=df["Low"], close=df["Close"], name="OHLC"), 
#                 row=1, col=1)

# %%
figure = go.Figure(
        data = [
            go.Candlestick(
            x=df.index, 
            close=df["Close"], 
            open=df["Open"], 
            high=df["High"],
            low=df["Low"],
            increasing_line_color = 'red',
            decreasing_line_color = 'red',
            )
        ]
)
figure.show()
# Out:
# <div>                            <div id="858c1813-1774-4455-91b0-ad1da1d824a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("858c1813-1774-4455-91b0-ad1da1d824a6")) {                    Plotly.newPlot(                        "858c1813-1774-4455-91b0-ad1da1d824a6",                        [{"close":[309.30999755859375,311.8599853515625,307.5400085449219,314.9800109863281,319.0299987792969,314.4200134277344,313.9200134277344,316.0400085449219,314.3500061035156,311.8599853515625,316.4100036621094,323.7699890136719,326.3599853515625,325.4200134277344,328.1099853515625,328.5899963378906,319.42999267578125,321.32000732421875,314.55999755859375,322.4200134277344,327.67999267578125,326.3800048828125,330.239990234375,331.3599853515625,333.5799865722656,333.510009765625,332.75,334.5799865722656,336.45001220703125,335.5400085449219,333.92999267578125,332.4700012207031,331.0199890136719,322.44000244140625,321.4800109863281,324.1300048828125,312.8299865722656,314.1400146484375,323.5899963378906,318.3999938964844,309.1600036621094,304.1000061035156,308.67999267578125,299.94000244140625,311.7699890136719,310.8800048828125,318.0400085449219,315.4599914550781,318.8299865722656,320.5799865722656,321.8999938964844,312.0400085449219,313.1400146484375,318.6099853515625,317.2200012207031,311.8699951171875,311.3299865722656,316.0,315.9100036621094,314.32000732421875,319.1300048828125,324.57000732421875,331.04998779296875,330.82000732421875,331.6199951171875,335.0799865722656,337.1099853515625,336.6700134277344,340.6000061035156,336.510009765625,341.6099853515625,342.010009765625,338.8800048828125,336.4100036621094,339.2900085449219,335.20001220703125,339.4200134277344,341.6300048828125,340.1499938964844,339.0,340.2200012207031,337.989990234375,336.19000244140625,
800048828125,336.4100036621094,339.2900085449219,335.20001220703125,339.4200134277344,341.6300048828125,340.1499938964844,339.0,340.2200012207031,337.989990234375,336.19000244140625,330.1400146484375,329.0299987792969,331.510009765625,334.20001220703125,325.760009765625,325.30999755859375,316.8900146484375,319.3399963378906,326.3900146484375,324.4100036621094,322.2200012207031,322.5899963378906,328.8299865722656,327.010009765625,332.510009765625,332.9700012207031,334.1300048828125,332.8800048828125,333.92999267578125,332.82000732421875,333.4700012207031,330.0,335.6000061035156,336.6000061035156,336.760009765625,336.8399963378906,340.3500061035156,341.239990234375,344.510009765625,342.260009765625,341.010009765625,345.3399963378906,342.6300048828125,344.3599853515625,347.57000732421875,347.739990234375,349.8900146484375,349.4599914550781,353.7099914550781,354.989990234375,354.42999267578125,354.57000732421875,358.6400146484375,360.19000244140625,360.95001220703125,358.7699890136719,361.010009765625,362.4200134277344,362.4200134277344,363.07000732421875,360.5199890136719,357.6000061035156,354.6700134277344,358.7900085449219,361.55999755859375,363.95001220703125,368.20001220703125,368.489990234375,364.42999267578125,365.8299865722656,366.4800109863281,364.57000732421875,364.6000061035156,366.80999755859375,367.3399963378906,369.6700134277344,368.04998779296875,368.7300109863281,366.8399963378906,366.2099914550781,367.5299987792969,368.82000732421875,368.9800109863281,365.7300109863281,362.2099914550781,363.9599914550781,367.7300109863281,373.2300109863281,374.3699951171875,374.79998779296875,372.4200134277344,376.0400085449219,380.260009765625,379.95001220703125,380.5799865722656,380.3999938964844,381.57000732421875,382.1099853515625,380.7799987792969,379.4700012207031,376.5899963378906,376.3299865722656,375.260009765625,378.04998779296875,378.30999755859375,373.8299865722656,365.70001220703125,366.1499938964844,369.57000732421875,372.9800109863281,373.3299865722656,370.3500061035156,359.8699951171875,359.2799987792969,357.9599914550781,360.17999267578125,352.6199951171875,357.3800048828125,359.6700134277344,362.9700012207031,361.160003 ...

# %%
close.plot()
# Out:
# <div>                            <div id="84c2df35-2b69-4812-8c83-59d5df3b7df7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84c2df35-2b69-4812-8c83-59d5df3b7df7")) {                    Plotly.newPlot(                        "84c2df35-2b69-4812-8c83-59d5df3b7df7",                        [{"hovertemplate":"variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close","orientation":"v","showlegend":true,"x":["2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-21T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00 ...

# %%
# figure.add_trace()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29736/3224935511.py in <module>
# ----> 1 figure.add_trace()
#
# TypeError: add_trace() missing 1 required positional argument: 'trace'

# %%
close['QQQ'].pct_change().plot(kind='hist')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# C:\Anaconda\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# C:\Anaconda\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#
# C:\Anaconda\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642         if res is None:
# --> 643             raise ParserError("Unknown string format: %s", timestr)
#     644
#
# ParserError: Unknown string format: QQQ
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     680             try:
# --> 681                 key = self._maybe_cast_for_get_loc(key)
#     682             except ValueError as err:
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\datetimes.py in _maybe_cast_for_get_loc(self, key)
#     708         # needed to localize naive datetimes or dates (GH 35690)
# --> 709         key = Timestamp(key)
#     710         if key.tzinfo is None:
#
# C:\Anaconda\lib\site-packages\pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# C:\Anaconda\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# C:\Anaconda\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# ValueError: could not convert string to Timestamp
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29736/2199734614.py in <module>
# ----> 1 close['QQQ'].pct_change().plot(kind='hist')
#
# C:\Anaconda\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# C:\Anaconda\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# C:\Anaconda\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     681                 key = self._maybe_cast_for_get_loc(key)
#     682             except ValueError as err:
# --> 683                 raise KeyError(key) from err
#     684
#     685         elif isinstance(key, timedelta):
#
# KeyError: 'QQQ'
