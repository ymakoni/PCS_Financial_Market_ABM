# %%
import datetime as dt
import pandas as pd
from pandas_datareader import data as pdr
import plotly.offline as plotly
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import yfinance as yf
yf.pdr_override()
import os
plotly.init_notebook_mode(connected=True)
pd.options.plotting.backend = 'plotly'
import wrds
import numpy as np
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## pandas_datareader module

# %%
total_SnP500_closing_10_years
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2013-12-02  0.02528  0.02528  0.02528  0.02528    0.02528   41538
# 2013-12-03  0.02528  0.02528  0.02528  0.02528    0.02528       0
# 2013-12-04  0.02528  0.02528  0.02528  0.02528    0.02528  138462
# 2013-12-05  0.02528  0.02528  0.02528  0.02528    0.02528       0
# 2013-12-06  0.02600  0.02672  0.02600  0.02672    0.02672   44308
# ...             ...      ...      ...      ...        ...     ...
# 2018-01-24  0.05500  0.05500  0.05500  0.05500    0.05500    7000
# 2018-01-25  0.05500  0.05500  0.05500  0.05500    0.05500    1160
# 2018-01-26  0.05000  0.05000  0.05000  0.05000    0.05000    1800
# 2018-01-29  0.06000  0.06000  0.05000  0.05000    0.05000   60817
# 2018-01-30  0.05000  0.05000  0.04500  0.05000    0.05000  150100
#
# [1048 rows x 6 columns]

# %%
# reference to dataset: https://www.nasdaq.com/market-activity/index/spx/historical
total_SnP500_closing_10_years = pd.read_csv(r'data/10 years total S&P closing.csv', parse_dates=True, index_col='Date')['Close/Last']
assert total_SnP500_closing_10_years.index.dtype == 'datetime64[ns]'

# %%
total_SnP500_closing_10_years.index
# Out:
# DatetimeIndex(['2023-01-27', '2023-01-26', '2023-01-25', '2023-01-24',
#                '2023-01-23', '2023-01-20', '2023-01-19', '2023-01-18',
#                '2023-01-17', '2023-01-13',
#                ...
#                '2013-02-12', '2013-02-11', '2013-02-08', '2013-02-07',
#                '2013-02-06', '2013-02-05', '2013-02-04', '2013-02-01',
#                '2013-01-31', '2013-01-30'],
#               dtype='datetime64[ns]', name='Date', length=2542, freq=None)

# %%
total_SnP500_closing_10_years.isna().sum()
# Out:
# 0

# %%
# no nans, looks good
df_total_SnP500_closing_10_years_clean = total_SnP500_closing_10_years

# %% [markdown]
# # Plotting Data

# %%
# Plotting mean (adj close) daily returns, averaged per day across  stocks:
df_total_SnP500_closing_10_years_clean.plot(title='Mean Daily closing of S&P500 index (39 years)')
# Out:
# <div>                            <div id="73271cae-4b0c-403e-9cd6-e4ccbc14ba62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73271cae-4b0c-403e-9cd6-e4ccbc14ba62")) {                    Plotly.newPlot(                        "73271cae-4b0c-403e-9cd6-e4ccbc14ba62",                        [{"hovertemplate":"variable=Close/Last<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Close/Last","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close/Last","showlegend":true,"x":["2023-01-27T00:00:00","2023-01-26T00:00:00","2023-01-25T00:00:00","2023-01-24T00:00:00","2023-01-23T00:00:00","2023-01-20T00:00:00","2023-01-19T00:00:00","2023-01-18T00:00:00","2023-01-17T00:00:00","2023-01-13T00:00:00","2023-01-1
# ...

# %%
df_total_SnP500_closing_10_years_clean.to_csv('data/df_total_SnP500_closing_10_years_clean.csv')

# %%
# saving the dataframes to csv files
